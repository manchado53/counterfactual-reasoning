# %% [markdown]
# # SMAC Counterfactual Analysis Demo
#
# This notebook demonstrates how to use the Counterfactual Reasoning framework with the StarCraft Multi-Agent Challenge (SMAC) environment.

# %%
import os
import sys
import numpy as np
from smac.env import StarCraft2Env

# Add src to path
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'src'))

from counterfactual_rl.environments.smac import CentralizedSmacWrapper
from counterfactual_rl.analysis.counterfactual import CounterfactualAnalyzer
from counterfactual_rl.environments import registry

# Set SC2 Path
os.environ['SC2PATH'] = r'C:\Program Files (x86)\StarCraft II'
print(f"SC2PATH: {os.environ['SC2PATH']}")
# Out:
# SC2PATH: C:\Program Files (x86)\StarCraft II

# %% [markdown]
# ## 1. Setup Environment
# We use the `CentralizedSmacWrapper` with global state (like a human player).

# %%
map_name = "3m"
env = StarCraft2Env(map_name=map_name, window_size_x=1, window_size_y=1)
wrapped_env = CentralizedSmacWrapper(env, use_state=True)  # Use global state

print(f"Environment initialized: {map_name}")
print(f"Joint Action Space: {wrapped_env.joint_action_space_size}")
# Out:
# Environment initialized: 3m
# Joint Action Space: 729

# %% [markdown]
# ## 2. Define a Random Agent
# Since we don't have a trained model yet, we'll use a dummy agent that takes random actions.

# %%
class RandomAgent:
    def __init__(self, action_space_size):
        self.action_space_size = action_space_size
        
    def predict(self, obs, deterministic=True):
        # Return random action and None (for state)
        return np.random.randint(0, self.action_space_size), None

model = RandomAgent(wrapped_env.joint_action_space_size)

# %% [markdown]
# ## 3. Run Counterfactual Analysis
# We initialize the analyzer with the SMAC state manager.
#
# **Note**: This will be slow due to the replay strategy (resetting and replaying actions for each counterfactual).

# %%
# Get State Manager from Registry
state_manager = registry.get_state_manager("SMAC-3m")

# Initialize analyzer (no env_config needed!)
analyzer = CounterfactualAnalyzer(
    model=model,
    env=wrapped_env,
    state_manager=state_manager,
    horizon=10,  # Shorter horizon for speed
    n_rollouts=1  # Fewer rollouts for speed
)

print("Analyzer initialized.")
# Out:
# Analyzer initialized.

# %%
# Run analysis on a single episode
print("Running analysis... (this may take a while due to replays)")
records = analyzer.evaluate_episode(max_steps=20, verbose=True)  # Limit steps for speed

print(f"Analysis complete! Analyzed {len(records)} state-action pairs.")
# Out:
# Running analysis... (this may take a while due to replays)
# WARNING:absl:SC2 isn't running, so bailing early on the websocket connection.
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Run analysis on a single episode
#       2 print("Running analysis... (this may take a while due to replays)")
# ----> 3 records = analyzer.evaluate_episode(max_steps=20, verbose=True)  # Limit steps for speed
#       5 print(f"Analysis complete! Analyzed {len(records)} state-action pairs.")
#
# File c:\Users\manchadoa\OneDrive - Milwaukee School of Engineering\ADRIAN LAPTOP SCHOOL\SEMESTERS\FALL 2025\UR Conterfactual Reasoning\counterfactual-reasoning\src\counterfactual_rl\analysis\counterfactual.py:268, in CounterfactualAnalyzer.evaluate_episode(self, max_steps, verbose, compute_all_metrics)
#     265 action = int(action)  # Convert numpy array to int
#     267 # Perform counterfactual rollouts for all actions
# --> 268 return_distributions = self.perform_counterfactual_rollouts(current_state)
#     270 # Compute metrics
#     271 if compute_all_metrics:
#     272     # Compute all distributional metrics
#
# File c:\Users\manchadoa\OneDrive - Milwaukee School of Engineering\ADRIAN LAPTOP SCHOOL\SEMESTERS\FALL 2025\UR Conterfactual Reasoning\counterfactual-reasoning\src\counterfactual_rl\analysis\counterfactual.py:102, in CounterfactualAnalyzer.perform_counterfactual_rollouts(self, state_dict)
#      98 returns = []
#     100 for _ in range(self.n_rollouts):
#     101     # Restore to the original state
# --> 102     self.state_manager.restore_state(self.env, state_dict)
#     104     # Execute the counterfactual action
#     105     obs, reward, terminated, truncated, info = self.env.step(action)
#
# File c:\Users\manchadoa\OneDrive - Milwaukee School of Engineering\ADRIAN LAPTOP SCHOOL\SEMESTERS\FALL 2025\UR Conterfactual Reasoning\counterfactual-reasoning\src\counterfactual_rl\environments\smac.py:157, in SmacStateManager.restore_state(env, state_dict)
#     155 """Restore state by REPLAYING history."""
#     156 # 1. Reset
# --> 157 env.reset(seed=state_dict.get('seed'))
#     159 # 2. Replay
#     160 history = state_dict['action_history']
#
# File c:\Users\manchadoa\OneDrive - Milwaukee School of Engineering\ADRIAN LAPTOP SCHOOL\SEMESTERS\FALL 2025\UR Conterfactual Reasoning\counterfactual-reasoning\src\counterfactual_rl\environments\smac.py:67, in CentralizedSmacWrapper.reset(self, seed, options)
#      63 self._seed = seed
#      65 # SMAC reset doesn't accept seed directly in all versions,
#      66 # but we store it for the StateManager to use if needed.
# ---> 67 obs, state = self.env.reset()
#      69 # Return flattened observation and info
#      70 return self._get_obs(), {}
#
# File ~\OneDrive - Milwaukee School of Engineering\ADRIAN LAPTOP SCHOOL\SEMESTERS\FALL 2025\UR Conterfactual Reasoning\playing-with-smac\smac\env\starcraft2\starcraft2.py:403, in StarCraft2Env.reset(self)
#     400 self._episode_steps = 0
#     401 if self._episode_count == 0:
#     402     # Launch StarCraft II
# --> 403     self._launch()
#     404 else:
#     405     self._restart()
#
# File ~\OneDrive - Milwaukee School of Engineering\ADRIAN LAPTOP SCHOOL\SEMESTERS\FALL 2025\UR Conterfactual Reasoning\playing-with-smac\smac\env\starcraft2\starcraft2.py:323, in StarCraft2Env._launch(self)
#     321 # Setting up the interface
#     322 interface_options = sc_pb.InterfaceOptions(raw=True, score=False)
# --> 323 self._sc2_proc = self._run_config.start(
#     324     window_size=self.window_size, want_rgb=False
#     325 )
#     326 self._controller = self._sc2_proc.controller
#     328 # Request to create the game
#
# File c:\Users\manchadoa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pysc2\run_configs\platforms.py:83, in LocalBase.start(***failed resolving arguments***)
#      80 if not os.path.exists(exec_path):
#      81   raise sc_process.SC2LaunchError("No SC2 binary found at: %s" % exec_path)
# ---> 83 return sc_process.StarcraftProcess(
#      84     self, exec_path=exec_path, version=self.version, **kwargs)
#
# File c:\Users\manchadoa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pysc2\lib\sc_process.py:137, in StarcraftProcess.__init__(self, run_config, exec_path, version, full_screen, extra_args, verbose, host, port, connect, timeout_seconds, window_size, window_loc, **kwargs)
#     135       self._proc = self._launch(run_config, args, **kwargs)
#     136     if connect:
# --> 137       self._controller = remote_controller.RemoteController(
#     138           self._host, self._port, self, timeout_seconds=timeout_seconds)
#     139 except:
#     140   self.close()
#
# File c:\Users\manchadoa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pysc2\lib\remote_controller.py:142, in RemoteController.__init__(self, host, port, proc, timeout_seconds)
#     140 def __init__(self, host, port, proc=None, timeout_seconds=None):
#     141   timeout_seconds = timeout_seconds or FLAGS.sc2_timeout
# --> 142   sock = self._connect(host, port, proc, timeout_seconds)
#     143   self._client = protocol.StarcraftProtocol(sock)
#     144   self._last_obs = None
#
# File c:\Users\manchadoa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pysc2\lib\stopwatch.py:205, in StopWatch.decorate.<locals>.decorator.<locals>._stopwatch(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def _stopwatch(*args, **kwargs):
#     204   with self(name):
# --> 205     return func(*args, **kwargs)
#
# File c:\Users\manchadoa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pysc2\lib\remote_controller.py:176, in RemoteController._connect(self, host, port, proc, timeout_seconds)
#     174       raise
#     175   time.sleep(1)
# --> 176 raise ConnectError("Failed to connect to the SC2 websocket. Is it up?")
#
# ConnectError: Failed to connect to the SC2 websocket. Is it up?

# %%
# Convert to DataFrame for analysis
import pandas as pd

data = []
for record in records:
    data.append({
        'step': record.step,
        'action': record.action,
        'consequence_score': record.consequence_score,
        'reward': record.reward
    })

df = pd.DataFrame(data)
df.head()

# %%
# Show high consequence states
consequential_states = df[df['consequence_score'] > 0.1]
print(f"Found {len(consequential_states)} consequential states (score > 0.1).")
consequential_states

# %%
# Plot consequence scores over time
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['consequence_score'], marker='o')
plt.xlabel('Step')
plt.ylabel('Consequence Score')
plt.title('Consequence Scores Over Episode')
plt.grid(True)
plt.show()
